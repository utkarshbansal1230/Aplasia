# %%
import pandas as pd

# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor  
from sklearn.metrics import mean_absolute_error


df_mine = pd.read_csv("/Users/utkarshbansal/Desktop/APLASIA/final.csv")


target_col = 'target_first_episode_duration'
id_col_name = 'chemo_hadm_id' 

if target_col not in df_mine.columns:
    raise ValueError(f"Column '{target_col}' not found!")

fold_files = [f'fold_{i}.pkl' for i in range(5)]
fold_maes = [] 

for fold_num, file_path in enumerate(fold_files):
    

    with open(file_path, 'rb') as f:
        original_train_ids, original_val_ids, original_test_ids = pickle.load(f)

   
    def filter_my_data(original_pairs):
        valid_hadm_ids = set([pair[1] for pair in original_pairs])
        return df_mine[df_mine[id_col_name].isin(valid_hadm_ids)]

    
    df_train = filter_my_data(original_train_ids)
    
    df_val   = filter_my_data(original_val_ids) 
    df_train_full = pd.concat([df_train, df_val]) 
    
    df_test  = filter_my_data(original_test_ids)

    print(f"\n" )
    print(f" PROCESSING FOLD {fold_num} (RANDOM FOREST) ".center(60, '#'))
    print(f"\n" )
    print(f"Samples -> Train : {len(df_train_full)}, Test: {len(df_test)}")

    
    drop_cols = [id_col_name, target_col]
    X_train_full = df_train_full.drop(columns=drop_cols)
    y_train_full = df_train_full[target_col] 
    
    X_test = df_test.drop(columns=drop_cols)
    y_test_original = df_test[target_col] 

   
    train_weights = df_train_full[target_col].apply(
        lambda x: 10.0 if x > 20 else (5.0 if x > 7 else 1.0)
    )

    model = RandomForestRegressor(
        n_estimators=200,       
        max_depth=None,          
        min_samples_split=5,     
        min_samples_leaf=2,      
        max_features='sqrt',     
        random_state=42,
        n_jobs=-1               
    )

   
    if len(X_train_full) > 0:
        model.fit(
            X_train_full, 
            y_train_full,
            sample_weight=train_weights 
        )

        if len(X_test) > 0:
            real_preds = model.predict(X_test)
            
            mae = mean_absolute_error(y_test_original, real_preds)
            fold_maes.append(mae)
            print(f"Fold {fold_num} MAE: {mae:.4f}")
            
            
            print("-" * 40)
            print(f"ERROR ANALYSIS FOR FOLD {fold_num}")
            
            fold_results = pd.DataFrame({
                'chemo_hadm_id': df_test[id_col_name],
                'Actual_Days': y_test_original.values,
                'Predicted_Days': real_preds,
                'Absolute_Error': np.abs(y_test_original.values - real_preds),
                'Raw_Residual': real_preds - y_test_original.values
            })

            
            print(f"\nActual Days Distribution (Test Set):")
            print(fold_results['Actual_Days'].describe()[['mean', 'std', 'min', '50%', 'max']])
            
            
            worst_10 = fold_results.sort_values(by='Absolute_Error', ascending=False).head(10)
            print("\n>>> TOP 10 WORST PREDICTIONS (Highest Error):")
            print(worst_10.to_string(index=False))

           
            best_10 = fold_results.sort_values(by='Absolute_Error', ascending=True).head(10)
            print("\n>>> TOP 10 BEST PREDICTIONS (Lowest Error):")
            print(best_10.to_string(index=False))
            
            
            bias = fold_results['Raw_Residual'].mean()
            print(f"\nAverage Bias (Pred - Actual): {bias:.4f}")
            status = "OVERESTIMATING" if bias > 0 else "UNDERESTIMATING"
            print(f"Status: Model is generally {status} stays in this fold.")

        else:
            print(f"Fold {fold_num}: No test samples found.")
    else:
        print(f"Fold {fold_num}: Not enough train/val samples.")

if len(fold_maes) > 0:
   
    print(f" FINAL SUBSET AVERAGE MAE: {np.mean(fold_maes):.4f} ".center(60, '='))
# Out:
# ############ PROCESSING FOLD 0 (RANDOM FOREST) #############
#
#
# Samples -> Train : 812, Test: 198
# Fold 0 MAE: 3.0900
# ----------------------------------------
# ERROR ANALYSIS FOR FOLD 0
#
# Actual Days Distribution (Test Set):
# mean     4.045455
# std      5.838169
# min      1.000000
# 50%      2.000000
# max     41.000000
# Name: Actual_Days, dtype: float64
#
# >>> TOP 10 WORST PREDICTIONS (Highest Error):
#  chemo_hadm_id  Actual_Days  Predicted_Days  Absolute_Error  Raw_Residual
#       21176832         41.0        9.128403       31.871597    -31.871597
#       22409075         41.0       12.926401       28.073599    -28.073599
#       27576498         25.0        7.726401       17.273599    -17.273599
#       25841662         24.0        7.134997       16.865003    -16.865003
#       24952654         19.0        4.931572       14.068428    -14.068428
#       28310302          2.0       12.508239       10.508239     10.508239
#       27253820         16.0        6.022815        9.977185     -9.977185
#       20237153          2.0       11.804671        9.804671      9.804671
#       22984596         18.0        8.458177        9.541823     -9.541823
#       25904767          1.0       10.392005        9.392005      9.392005
#
# >>> TOP 10 BEST PREDICTIONS (Lowest Error):
#  chemo_hadm_id  Actual_Days  Predicted_Days  Absolute_Error  Raw_Residual
#       28102412          2.0        1.957650        0.042350     -0.042350
#       24032784          4.0        4.067783        0.067783      0.067783
#       28333139          2.0        2.082015        0.082015      0.082015
#       23003430          7.0        7.121158        0.121158      0.121158
#       24035452          3.0        2.831063        0.168937     -0.168937
#       29866259          2.0        2.195950        0.195950      0.195950
#       24145375          3.0        2.779850        0.220150     -0.220150
#       26280750          5.0        5.302364        0.302364      0.302364
#       25489089          3.0        2.695826        0.304174     -0.304174
#       23824479          1.0        1.332804        0.332804      0.332804
#
# Average Bias (Pred - Actual): 0.2005
# Status: Model is generally OVERESTIMATING stays in this fold.
#
#
# ############ PROCESSING FOLD 1 (RANDOM FOREST) #############
#
#
# Samples -> Train : 806, Test: 204
# Fold 1 MAE: 3.1616
# ----------------------------------------
# ERROR ANALYSIS FOR FOLD 1
#
# Actual Days Distribution (Test Set):
# mean     3.573529
# std      5.074760
# min      1.000000
# 50%      1.000000
# max     39.000000
# Name: Actual_Days, dtype: float64
#
# >>> TOP 10 WORST PREDICTIONS (Highest Error):
#  chemo_hadm_id  Actual_Days  Predicted_Days  Absolute_Error  Raw_Residual
#       27627583         39.0       13.261371       25.738629    -25.738629
#       25602577         24.0        8.591023       15.408977    -15.408977
#       28095196         22.0        6.721106       15.278894    -15.278894
#       21061637         20.0        5.812931       14.187069    -14.187069
#       27756905         22.0        8.909888       13.090112    -13.090112
#       26720988          1.0       12.840825       11.840825     11.840825
#       24611960          1.0       11.966739       10.966739     10.966739
#       27001360         19.0        8.263964       10.736036    -10.736036
#       22896990         16.0        5.353682       10.646318    -10.646318
#       27845956         17.0        6.488493       10.511507    -10.511507
#
# >>> TOP 10 BEST PREDICTIONS (Lowest Error):
#  chemo_hadm_id  Actual_Days  Predicted_Days  Absolute_Error  Raw_Residual
#       29107281          4.0        3.984313        0.015687     -0.015687
#       27991856          6.0        6.025393        0.025393      0.025393
#       21938223          3.0        2.957416        0.042584     -0.042584
#       26346065          3.0        2.942193        0.057807     -0.057807
#       25924705          9.0        9.060416        0.060416      0.060416
#       27035769          2.0        1.926294        0.073706     -0.073706
#       23360270          4.0        4.078231        0.078231      0.078231
#       25239968          8.0        7.903046        0.096954     -0.096954
#       27267043         10.0       10.113393        0.113393      0.113393
#       28938929          3.0        3.130944        0.130944      0.130944
#
# Average Bias (Pred - Actual): 0.9232
# Status: Model is generally OVERESTIMATING stays in this fold.
#
#
# ############ PROCESSING FOLD 2 (RANDOM FOREST) #############
#
#
# Samples -> Train : 803, Test: 207
# Fold 2 MAE: 2.9839
# ----------------------------------------
# ERROR ANALYSIS FOR FOLD 2
#
# Actual Days Distribution (Test Set):
# mean     3.676329
# std      4.964590
# min      1.000000
# 50%      1.000000
# max     36.000000
# Name: Actual_Days, dtype: float64
#
# >>> TOP 10 WORST PREDICTIONS (Highest Error):
#  chemo_hadm_id  Actual_Days  Predicted_Days  Absolute_Error  Raw_Residual
#       21095202         36.0        4.228273       31.771727    -31.771727
#       29179248         32.0        5.354076       26.645924    -26.645924
#       26810553          1.0       15.852879       14.852879     14.852879
#       26576581         18.0        3.713329       14.286671    -14.286671
#       26870854          1.0       14.761698       13.761698     13.761698
#       27197133          1.0       14.147722       13.147722     13.147722
#       20114040          1.0       13.082693       12.082693     12.082693
#       27760716         19.0        8.356523       10.643477    -10.643477
#       20548095         16.0        6.343091        9.656909     -9.656909
#       27510205         20.0       11.663718        8.336282     -8.336282
#
# >>> TOP 10 BEST PREDICTIONS (Lowest Error):
#  chemo_hadm_id  Actual_Days  Predicted_Days  Absolute_Error  Raw_Residual
#       21403255          2.0        1.986680        0.013320     -0.013320
#       27869590         11.0       10.907070        0.092930     -0.092930
#       26572517          6.0        5.882097        0.117903     -0.117903
#       28916921          3.0        2.881988        0.118012     -0.118012
#       24436207          3.0        2.879000        0.121000     -0.121000
#       29361787          3.0        3.168812        0.168812      0.168812
#       24821247          7.0        6.808626        0.191374     -0.191374
#       20947394          3.0        2.802358        0.197642     -0.197642
#       27114646          5.0        5.227006        0.227006      0.227006
#       27769399          4.0        4.240050        0.240050      0.240050
#
# Average Bias (Pred - Actual): 0.6408
# Status: Model is generally OVERESTIMATING stays in this fold.
#
#
# ############ PROCESSING FOLD 3 (RANDOM FOREST) #############
#
#
# Samples -> Train : 816, Test: 194
# Fold 3 MAE: 3.6633
# ----------------------------------------
# ERROR ANALYSIS FOR FOLD 3
#
# Actual Days Distribution (Test Set):
# mean     4.757732
# std      6.450133
# min      1.000000
# 50%      2.000000
# max     38.000000
# Name: Actual_Days, dtype: float64
#
# >>> TOP 10 WORST PREDICTIONS (Highest Error):
#  chemo_hadm_id  Actual_Days  Predicted_Days  Absolute_Error  Raw_Residual
#       28668281         38.0        4.851525       33.148475    -33.148475
#       25939760         38.0        8.767905       29.232095    -29.232095
#       20866387         30.0        9.459175       20.540825    -20.540825
#       28627528         23.0        4.288716       18.711284    -18.711284
#       27804451         23.0        5.066989       17.933011    -17.933011
#       21758938         19.0        3.481471       15.518529    -15.518529
#       22491397         23.0        8.805639       14.194361    -14.194361
#       29351840         19.0        5.663046       13.336954    -13.336954
#       28136206         19.0        6.314491       12.685509    -12.685509
#       26350604         18.0        7.874542       10.125458    -10.125458
#
# >>> TOP 10 BEST PREDICTIONS (Lowest Error):
#  chemo_hadm_id  Actual_Days  Predicted_Days  Absolute_Error  Raw_Residual
#       22543586          4.0        3.946885        0.053115     -0.053115
#       22679319          3.0        2.931220        0.068780     -0.068780
#       24848905          3.0        3.072440        0.072440      0.072440
#       20743102          3.0        2.925858        0.074142     -0.074142
#       23457426          4.0        3.772995        0.227005     -0.227005
#       28664852          6.0        5.746707        0.253293     -0.253293
#       21707772          5.0        5.355070        0.355070      0.355070
#       23921666          2.0        2.413000        0.413000      0.413000
#       24010953          2.0        1.586439        0.413561     -0.413561
#       20165082          3.0        3.442366        0.442366      0.442366
#
# Average Bias (Pred - Actual): -0.2049
# Status: Model is generally UNDERESTIMATING stays in this fold.
#
#
# ############ PROCESSING FOLD 4 (RANDOM FOREST) #############
#
#
# Samples -> Train : 803, Test: 207
# Fold 4 MAE: 3.1061
# ----------------------------------------
# ERROR ANALYSIS FOR FOLD 4
#
# Actual Days Distribution (Test Set):
# mean     3.512077
# std      4.809840
# min      1.000000
# 50%      1.000000
# max     36.000000
# Name: Actual_Days, dtype: float64
#
# >>> TOP 10 WORST PREDICTIONS (Highest Error):
#  chemo_hadm_id  Actual_Days  Predicted_Days  Absolute_Error  Raw_Residual
#       24358862         36.0       11.625491       24.374509    -24.374509
#       20478619         26.0        7.579374       18.420626    -18.420626
#       20399542         25.0        6.861486       18.138514    -18.138514
#       22150768         19.0        6.509317       12.490683    -12.490683
#       29798426          1.0       10.643114        9.643114      9.643114
#       26014636          1.0       10.597366        9.597366      9.597366
#       22768239          1.0        9.910919        8.910919      8.910919
#       28693965         13.0        4.184174        8.815826     -8.815826
#       28186439         16.0        7.245199        8.754801     -8.754801
#       23498337          1.0        9.688550        8.688550      8.688550
#
# >>> TOP 10 BEST PREDICTIONS (Lowest Error):
#  chemo_hadm_id  Actual_Days  Predicted_Days  Absolute_Error  Raw_Residual
#       24430445          7.0        6.990581        0.009419     -0.009419
#       24889647          5.0        4.927005        0.072995     -0.072995
#       27101189          5.0        4.919437        0.080563     -0.080563
#       24909264          3.0        2.837470        0.162530     -0.162530
#       29196653          2.0        2.180053        0.180053      0.180053
#       23192730          4.0        3.813246        0.186754     -0.186754
#       20251307          3.0        3.216709        0.216709      0.216709
#       26026627          3.0        2.772916        0.227084     -0.227084
#       21745306          3.0        2.750331        0.249669     -0.249669
#       29278153          3.0        3.333424        0.333424      0.333424
#
# Average Bias (Pred - Actual): 0.6703
# Status: Model is generally OVERESTIMATING stays in this fold.
# ============= FINAL SUBSET AVERAGE MAE: 3.2010 =============
